# %%
# %cd Entropy/src/studies/
# Out:
# /home/simone/Desktop/DSSC/tirocinio/Entropy/src/studies

# %%
from qiskit_vs_mycode_result import *
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mytimes = [my_time_5,my_time_6,my_time_7,my_time_8]
qtimes = [qiskit_time_5,qiskit_time_6,qiskit_time_7,qiskit_time_8]

# %%
plot(range(5,9),np.log2(mytimes), '-o', color='blue', label = "W implementation")
plot(range(5,9),np.log2(qtimes), '-o', color='orange', label = "qiskit")
legend()
title("Semilog scaling on 500 bipartitions")
xticks(range(5,9))
xlabel("L")
ylabel("log(time)")
savefig("qiskit_vs_mycode_scaling_log")
show()
